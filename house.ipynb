# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df=pd.DataFrame(pd.read_csv('Housing.csv'))

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
cname =  ['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea','furnishingstatus']
def bimap(x):
    return x.map({'yes': 1, "no": 0,'furnished':0,'semi-furnished':1,'unfurnished':2})
df[cname] = df[cname].apply(bimap)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0

# %%
fn=['price','area','bedrooms','bathrooms','stories','mainroad', 'guestroom', 'basement',
      'airconditioning','parking', 'prefarea','furnishingstatus']
xn=fn[1:]
x=df[xn]
y=df['price']

# %%
x.head()
# Out:
#    area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0  7420         4          2        3         1          0         0
# 1  8960         4          4        4         1          0         0
# 2  9960         3          2        2         1          0         1
# 3  7500         4          2        2         1          0         1
# 4  7420         4          1        2         1          1         1
#
#    airconditioning  parking  prefarea  furnishingstatus
# 0                1        2         1                 0
# 1                1        3         0                 0
# 2                0        2         1                 1
# 3                1        3         1                 0
# 4                1        2         0                 0

# %%
y.head()
# Out:
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# Name: price, dtype: int64

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=44)

# %%
model=LinearRegression()
model.fit(xtrain,ytrain)
ypred=model.predict(xtest)
print("R-square value:",metrics.r2_score(ytest,ypred))
# Out:
# Accuracy: 0.7409957389009919
